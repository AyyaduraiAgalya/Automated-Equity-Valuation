# %% [markdown]
# ## Modelling the AR(1) on Revenue Growth for various sectors

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /opt/anaconda3/lib/python3.12/site-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in /opt/anaconda3/lib/python3.12/site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /opt/anaconda3/lib/python3.12/site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /opt/anaconda3/lib/python3.12/site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in /opt/anaconda3/lib/python3.12/site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/lib/python3.12/site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.12/site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)

# %%
import sys
from pathlib import Path

root_dir = Path.cwd().parent  # Go one folder up from /notebooks
print("Root directory:", root_dir)

if str(root_dir) not in sys.path:
    sys.path.append(str(root_dir))
    
import pandas as pd
df = pd.read_parquet("../data/enriched/financials_annual_ticker_sic.parquet")
df.head()
# Out:
# Root directory: /Users/agalyaayyadurai/Automated-Equity-Valuation
#                    adsh   cik      name  form    fy  fp    period      filed  \
# 0  0001047469-11-006302  1750  AAR CORP  10-K  2011  FY  20110531 2011-07-13
# 1  0001047469-12-007300  1750  AAR CORP  10-K  2012  FY  20120531 2012-07-19
# 2  0001047469-13-007797  1750  AAR CORP  10-K  2013  FY  20130531 2013-07-26
# 3  0001047469-14-006243  1750  AAR CORP  10-K  2014  FY  20140531 2014-07-17
# 4  0001047469-15-006136  1750  AAR CORP  10-K  2015  FY  20150531 2015-07-15
#
#     sic source_zip  ... WASODiluted       bs_diff bs_balanced_flag  \
# 0  3720     2011q3  ...         NaN  8.678820e+08            False
# 1  3720     2012q3  ...         NaN  1.331004e+09            False
# 2  3720     2013q3  ...         NaN  1.218300e+09            False
# 3  3720     2014q3  ...         NaN  1.200000e+09            False
# 4  3720     2015q3  ...         NaN  6.699000e+08            False
#
#   cf_delta_abs cf_balanced_flag  coverage_score  WASOCombinedBasicDiluted  \
# 0   21964000.0            False        0.583333                       NaN
# 1          0.0             True        0.333333                       NaN
# 2    6400000.0            False        0.583333                       NaN
# 3   13000000.0            False        0.583333                       NaN
# 4   31900000.0            False        0.583333                       NaN
#
#    ticker                   office    industry_title
# 0     AIR  Office of Manufacturing  AIRCRAFT & PARTS
# 1     AIR  Office of Manufacturing  AIRCRAFT & PARTS
# 2     AIR  Office of Manufacturing  AIRCRAFT & PARTS
# 3     AIR  Office of Manufacturing  AIRCRAFT & PARTS
# 4     AIR  Office of Manufacturing  AIRCRAFT & PARTS
#
# [5 rows x 74 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89478 entries, 0 to 89477
# Data columns (total 74 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   adsh                        89478 non-null  object
#  1   cik                         89478 non-null  Int64
#  2   name                        89478 non-null  object
#  3   form                        89478 non-null  object
#  4   fy                          89478 non-null  Int64
#  5   fp                          89478 non-null  object
#  6   period                      89478 non-null  object
#  7   filed                       89478 non-null  datetime64[ns]
#  8   sic                         89086 non-null  Int64
#  9   source_zip                  89478 non-null  object
#  10  instance                    89478 non-null  object
#  11  fye                         89478 non-null  object
#  12  accepted                    89478 non-null  object
#  13  countryba                   89309 non-null  object
#  14  stprba                      84075 non-null  object
#  15  AccountsPayable             63181 non-null  float64
#  16  AccountsReceivable          46678 non-null  float64
#  17  CashAndCashEquivalents      80113 non-null  float64
#  18  Goodwill                    39228 non-null  float64
#  19  Intangibles                 39154 non-null  float64
#  20  Inventory                   35339 non-null  float64
#  21  LongTermDebt                26758 non-null  float64
#  22  OtherCurrentLiabilities     55411 non-null  float64
#  23  OtherNoncurrentLiabilities  40536 non-null  float64
#  24  PPandE                      64934 non-null  float64
#  25  RetainedEarnings            79457 non-null  float64
#  26  ShareholdersEquity          84493 non-null  float64
#  27  ShortTermDebt               26925 non-null  float64
#  28  ShortTermInvestments        7850 non-null   float64
#  29  TotalAssets                 88092 non-null  float64
#  30  TotalCurrentAssets          68751 non-null  float64
#  31  TotalCurrentLiabilities     68797 non-null  float64
#  32  TotalLiabilities            70718 non-null  float64
#  33  TotalNoncurrentAssets       5708 non-null   float64
#  34  TreasuryStock               26854 non-null  float64
#  35  CostOfRevenue               33267 non-null  float64
#  36  DepAmort                    23196 non-null  float64
#  37  GrossProfit                 31671 non-null  float64
#  38  IncomeTaxExpense            61579 non-null  float64
#  39  InterestExpense             61443 non-null  float64
#  40  NetIncome                   83997 non-null  float64
#  41  OperatingExpenses           58364 non-null  float64
#  42  OperatingIncome             65411 non-null  float64
#  43  OtherIncomeExpense          58436 non-null  float64
#  44  PretaxIncome                44231 non-null  float64
#  45  RND                         23902 non-null  float64
#  46  Revenue                     62537 non-null  float64
#  47  SGA                         69685 non-null  float64
#  48  CFF                         72424 non-null  float64
#  49  CFI                         66690 non-null  float64
#  50  CFO                         73650 non-null  float64
#  51  CapEx                       55597 non-null  float64
#  52  DebtIssuance                17219 non-null  float64
#  53  DebtRepayment               31313 non-null  float64
#  54  DepAmortCF                  67467 non-null  float64
#  55  EquityIssuance              46360 non-null  float64
#  56  IncomeTaxesPaid             45871 non-null  float64
#  57  InterestPaid                52585 non-null  float64
#  58  ProceedsFromSalePPE         18702 non-null  float64
#  59  ShareRepurchase             29655 non-null  float64
#  60  StockBasedComp              57832 non-null  float64
#  61  CommonSharesIssued          79751 non-null  float64
#  62  CommonSharesOutstanding     76355 non-null  float64
#  63  WASOBasic                   48175 non-null  float64
#  64  WASODiluted                 45287 non-null  float64
#  65  bs_diff                     88092 non-null  float64
#  66  bs_balanced_flag            89478 non-null  bool
#  67  cf_delta_abs                89478 non-null  float64
#  68  cf_balanced_flag            89478 non-null  bool
#  69  coverage_score              89478 non-null  float64
#  70  WASOCombinedBasicDiluted    20286 non-null  float64
#  71  ticker                      77057 non-null  object
#  72  office                      89086 non-null  object
#  73  industry_title              89086 non-null  object
# dtypes: Int64(3), bool(2), datetime64[ns](1), float64(54), object(14)
# memory usage: 49.6+ MB

# %%
import numpy as np

# 1) Remove missing or non-positive revenue
df_cleaned = df.dropna(subset=["Revenue"]).copy()
df_cleaned = df_cleaned[df_cleaned["Revenue"] > 0].copy()

# 2) Ensure period is datetime (if not already)
df_cleaned["period"] = pd.to_datetime(df_cleaned["period"])

# 3) Sort for time-series ordering
df_cleaned = df_cleaned.sort_values(["cik", "period"]).copy()

# 4) Compute log revenue and lag
df_cleaned["log_rev"] = np.log(df_cleaned["Revenue"])
df_cleaned["log_rev_lag"] = df_cleaned.groupby("cik")["log_rev"].shift(1)

# 5) Compute log revenue growth g
df_cleaned["g"] = df_cleaned["log_rev"] - df_cleaned["log_rev_lag"]

# Keep only valid growth observations
df_cleaned = df_cleaned.dropna(subset=["g"]).copy()

# 6) Keep only CIKs with min 4 growth observations (≈ 5 years of data)
growth_counts = df_cleaned.groupby("cik")["g"].size()
valid_ciks = growth_counts[growth_counts >= 4].index
df_cleaned = df_cleaned[df_cleaned["cik"].isin(valid_ciks)].copy()

# 7) Build AR(1) input variable: g_lag
df_cleaned["g_lag"] = df_cleaned.groupby("cik")["g"].shift(1)
df_cleaned = df_cleaned.dropna(subset=["g_lag"]).copy()

df_cleaned.head()
# Out:
#                    adsh   cik      name  form    fy  fp     period      filed  \
# 2  0001047469-13-007797  1750  AAR CORP  10-K  2013  FY 2013-05-31 2013-07-26
# 3  0001047469-14-006243  1750  AAR CORP  10-K  2014  FY 2014-05-31 2014-07-17
# 4  0001047469-15-006136  1750  AAR CORP  10-K  2015  FY 2015-05-31 2015-07-15
# 5  0001047469-16-014299  1750  AAR CORP  10-K  2016  FY 2016-05-31 2016-07-13
# 6  0001047469-17-004528  1750  AAR CORP  10-K  2017  FY 2017-05-31 2017-07-12
#
#     sic source_zip  ... cf_balanced_flag coverage_score  \
# 2  3720     2013q3  ...            False       0.583333
# 3  3720     2014q3  ...            False       0.583333
# 4  3720     2015q3  ...            False       0.583333
# 5  3720     2016q3  ...            False       0.583333
# 6  3720     2017q3  ...            False       0.583333
#
#   WASOCombinedBasicDiluted ticker                   office    industry_title  \
# 2                      NaN    AIR  Office of Manufacturing  AIRCRAFT & PARTS
# 3                      NaN    AIR  Office of Manufacturing  AIRCRAFT & PARTS
# 4                      NaN    AIR  Office of Manufacturing  AIRCRAFT & PARTS
# 5                      NaN    AIR  Office of Manufacturing  AIRCRAFT & PARTS
# 6                      NaN    AIR  Office of Manufacturing  AIRCRAFT & PARTS
#
#      log_rev  log_rev_lag         g     g_lag
# 2  21.482809    21.448395  0.034414  0.150888
# 3  21.433762    21.482809 -0.049048  0.034414
# 4  21.189701    21.433762 -0.244061 -0.049048
# 5  21.231648    21.189701  0.041948 -0.244061
# 6  21.292889    21.231648  0.061240  0.041948
#
# [5 rows x 78 columns]

# %%
import pandas as pd

def filter_and_tag_sectors(df: pd.DataFrame, sic_col: str = "sic"):
    """
    Filter a fundamentals DataFrame to selected SIC-based sectors/sub-sectors
    and add 'sector' and 'sub_sector' columns.

    Parameters
    ----------
    df : pd.DataFrame
        Input DataFrame containing at least the SIC code column.
    sic_col : str, default "SIC"
        Name of the column in df that contains the SIC code.

    Returns
    -------
    pd.DataFrame
        Filtered DataFrame with two new columns: 'sector' and 'sub_sector'.
    """

    # --- 1. Define the sector / sub-sector structure by SIC code ---
    sector_structure = {
        "Technology & Communication": {
            # Core hardware & equipment
            "Electronic Computers": [3571],
            "Computer Storage Devices": [3572],
            "Computer & Office Equipment – Other": [3575, 3576, 3577, 3578, 3579],
    
            # Communications equipment & components
            "Radio & TV Broadcasting & Communications Equipment": [3661, 3663, 3669],
            "Electronic Components & Accessories": [3670, 3672, 3677, 3678, 3679],
            "Semiconductors & Related Devices": [3674],
    
            # Software & IT services
            "Prepackaged Software": [7372],
            "IT Services & Data Processing": [7370, 7371, 7373, 7374],
    
            # Telecom services
            "Telecom Services": [4812, 4813, 4899],
        },
    
        "Health Care & Life Sciences": {
            "Pharmaceutical Preparations": [2834],
            "Biological Products": [2836],
            "Diagnostic Substances (In Vitro & In Vivo)": [2835],
            "Surgical & Medical Instruments": [3841],
            "General Medical & Surgical Hospitals": [8062],
        },
    
        "Financials": {
            "National Commercial Banks": [6021],
            "State Commercial Banks": [6022],
            "Security Brokers & Dealers": [6211],
            "Investment Advice": [6282],
            "Real Estate Investment Trusts (REITs)": [6798],
        },
    
        "Consumer (Staples & Discretionary)": {
            # --- Staples (Defensive) ---
            "Retail – Grocery Stores": [5411],
            "Packaged Foods": [2030, 2050, 2090],       # Canned, bakery, misc foods
            "Soft Drinks & Carbonated Waters": [2086],
            "Household & Personal Care Products": [2842, 2844],  # Cleaning + cosmetics
    
            # --- General retail & e-commerce ---
            "General Merchandise & Department Stores": [5311, 5399],
            "E-Commerce / Nonstore Retail": [5960, 5961],
    
            # --- Foodservice / restaurants ---
            "Restaurants & Eating Places": [5812],
    
            # --- Apparel & shoes ---
            "Apparel & Clothing Stores": [5600, 5621, 5651],
            "Shoe Stores": [5661],
    
            # --- Home & furniture / building supplies ---
            "Home Furniture & Furnishings Stores": [5700, 5712],
            "Home Improvement & Building Materials (Retail)": [5200, 5211],
    
            # --- Autos & related retail ---
            "Automotive Manufacturing & Parts": [3711, 3713, 3714, 3715],
            "Auto Dealers & Service Stations": [5500, 5531],
    
            # --- Specialty & hobby retail ---
            "Retail – Hobby, Toy & Game Shops": [5945],
            "Consumer Electronics Stores": [5731],
    
            # --- Entertainment, leisure & recreation ---
            "Entertainment & Recreation Services": [7900, 7990, 7997, 7948],
            "Motion Picture & Video Exhibition & Rental": [7830, 7841],
            "Motion Picture & Video Production/Distribution": [7812, 7822, 7829],
    
            # --- Hotels & lodging ---
            "Hotels, Motels & Lodging": [7000, 7011],
        },
    
        "Energy, Utilities & Infrastructure": {
            # Upstream, midstream, downstream
            "Crude Petroleum & Natural Gas": [1311],
            "Oil & Gas Field Services & Equipment": [1381, 1382, 1389, 3533],
            "Coal & Consumable Fuels": [1220, 1221],
            "Petroleum Refining": [2911],
            "Pipelines (Excl. Natural Gas)": [4610],
    
            # Utilities & energy services
            "Electric Services": [4911],
            "Natural Gas Transmission & Distribution": [4922, 4923, 4924],
            "Electric & Other Services Combined": [4931],
            "Gas & Other Services Combined": [4932],
            "Electric, Gas & Sanitary Services – Other": [4900],
    
            # Waste, steam & cogeneration
            "Refuse & Waste Management": [4953, 4955],
            "Steam & Air-Conditioning Supply": [4961],
            "Cogeneration & Small Power Producers": [4991],
        },
    }



    # --- 2. Build lookup dicts: SIC -> sector, SIC -> sub_sector ---
    sic_to_sector = {}
    sic_to_sub = {}

    for sector, subs in sector_structure.items():
        for sub_name, sic_list in subs.items():
            for sic in sic_list:
                sic_to_sector[sic] = sector
                sic_to_sub[sic] = sub_name

    # --- 3. Normalize SIC column to numeric (in case it's string) ---
    df = df.copy()
    df[sic_col] = pd.to_numeric(df[sic_col], errors="coerce").astype("Int64")

    # --- 4. Filter to only the chosen SIC codes ---
    valid_sics = set(sic_to_sector.keys())
    mask = df[sic_col].isin(valid_sics)
    filtered = df[mask].copy()

    # --- 5. Map sector and sub_sector ---
    filtered["sector"] = filtered[sic_col].map(sic_to_sector)
    filtered["sub_sector"] = filtered[sic_col].map(sic_to_sub)

    return filtered

# %%
# Example: df_fundamentals already has columns like ['SIC', 'Office', 'Industry Title', ...]
filtered_df = filter_and_tag_sectors(df_cleaned, sic_col="sic")

# Now filtered_df:
# - only contains rows with the chosen SIC codes
# - has two new columns: 'sector' and 'sub_sector'

# %%
filtered_df["sector"].value_counts()
# Out:
# sector
# Technology & Communication            5856
# Health Care & Life Sciences           3985
# Consumer (Staples & Discretionary)    3303
# Financials                            3297
# Energy, Utilities & Infrastructure    3224
# Name: count, dtype: int64

# %%
unique_ciks_per_sub = (
    filtered_df
    .groupby("sub_sector")["cik"]
    .nunique()
    .reset_index(name="unique_cik_count")
    .sort_values("unique_cik_count", ascending=False)
)

print(unique_ciks_per_sub)
# Out:
#                                            sub_sector  unique_cik_count
# 17                        Pharmaceutical Preparations               981
# 18                               Prepackaged Software               581
# 20              Real Estate Investment Trusts (REITs)               497
# 3                       Crude Petroleum & Natural Gas               416
# 29                             State Commercial Banks               406
# 1                                 Biological Products               274
# 30                     Surgical & Medical Instruments               268
# 13                          National Commercial Banks               219
# 26                   Semiconductors & Related Devices               205
# 21                        Restaurants & Eating Places               120
# 14            Natural Gas Transmission & Distribution               119
# 7                                   Electric Services               113
# 5                   E-Commerce / Catalog & Mail Order                90
# 12                                  Investment Advice                77
# 19  Radio & TV Broadcasting & Communications Equip...                73
# 11                   Household/Personal Care Products                66
# 25                         Security Brokers & Dealers                65
# 0                           Apparel & Clothing Stores                60
# 15                                     Packaged Foods                51
# 4          Diagnostic Substances (In Vitro & In Vivo)                48
# 6                  Electric & Other Services Combined                42
# 16                                 Petroleum Refining                41
# 23                            Retail – Grocery Stores                26
# 9                General Medical & Surgical Hospitals                22
# 2                            Computer Storage Devices                22
# 28                    Soft Drinks & Carbonated Waters                18
# 8                                Electronic Computers                17
# 10            General Merchandise & Department Stores                15
# 27                                        Shoe Stores                 8
# 22                          Retail – Furniture Stores                 6
# 24                   Retail – Hobby, Toy & Game Shops                 6

# %%
filtered_df['has_revenue'] = filtered_df['Revenue'].notna().astype(int)

coverage = (
    filtered_df.groupby('sector')['has_revenue']
      .agg(records='count', with_revenue='sum')
      .assign(pct_with_revenue=lambda x: x['with_revenue'] / x['records'] * 100)
)

print(coverage)
# Out:
#                                     records  with_revenue  pct_with_revenue
# sector
# Consumer (Staples & Discretionary)     3303          3303             100.0
# Energy, Utilities & Infrastructure     3224          3224             100.0
# Financials                             3297          3297             100.0
# Health Care & Life Sciences            3985          3985             100.0
# Technology & Communication             5856          5856             100.0

# %% [markdown]
# ## Is Revenue growth mean reverting??

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=filtered_df, x="sector", y="g")
plt.axhline(0, linestyle="--")
plt.show()

# %%
## Auto correlation function of growth

from statsmodels.graphics.tsaplots import plot_acf

# Example: sector-level average growth per year
df_acf = filtered_df.copy()
df_acf["year"] = df_acf["period"].dt.year

tech_yearly = (
    df_acf[df_acf["sector"] == "Technology & Communication"]
    .groupby("year")["g"].mean()
    .sort_index()
)

plot_acf(tech_yearly, lags=8)
plt.show()

# %%
# ADF and KPSS Tests

from statsmodels.tsa.stattools import adfuller, kpss
import numpy as np
import pandas as pd

def sector_stationarity_tests(df):
    df = df.copy()
    df["year"] = df["period"].dt.year

    results = []

    for sector, d in df.groupby("sector"):
        # sector-level annual average growth
        ts = (
            d.groupby("year")["g"]
            .mean()
            .sort_index()
        ).dropna()

        if len(ts) < 8:  # not enough time points for a meaningful test
            continue

        # ADF: H0 = unit root (non-stationary)
        adf_stat, adf_p, _, _, adf_crit, _ = adfuller(ts, autolag="AIC")

        # KPSS: H0 = stationary
        try:
            kpss_stat, kpss_p, _, kpss_crit = kpss(ts, regression="c", nlags="auto")
        except ValueError:
            kpss_stat, kpss_p, kpss_crit = np.nan, np.nan, {}

        results.append({
            "sector": sector,
            "n_years": len(ts),
            "adf_stat": adf_stat,
            "adf_pvalue": adf_p,
            "kpss_stat": kpss_stat,
            "kpss_pvalue": kpss_p,
        })

    return pd.DataFrame(results)

stationarity_results = sector_stationarity_tests(filtered_df)
print(stationarity_results)
# Out:
#                                sector  n_years  adf_stat    adf_pvalue  \
# 0  Consumer (Staples & Discretionary)       15 -1.424039  5.706987e-01
# 1  Energy, Utilities & Infrastructure       15 -2.125131  2.345302e-01
# 2                          Financials       15 -2.060224  2.608066e-01
# 3         Health Care & Life Sciences       15 -5.855256  3.512352e-07
# 4          Technology & Communication       15 -3.464217  8.955072e-03
#
#    kpss_stat  kpss_pvalue
# 0   0.127255     0.100000
# 1   0.063683     0.100000
# 2   0.127507     0.100000
# 3   0.500000     0.041667
# 4   0.060940     0.100000
# /var/folders/zz/l0v68lmx1_1fxy9jgn7ynjkw0000gn/T/ipykernel_4462/3192953128.py:29: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_stat, kpss_p, _, kpss_crit = kpss(ts, regression="c", nlags="auto")
# /var/folders/zz/l0v68lmx1_1fxy9jgn7ynjkw0000gn/T/ipykernel_4462/3192953128.py:29: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_stat, kpss_p, _, kpss_crit = kpss(ts, regression="c", nlags="auto")
# /var/folders/zz/l0v68lmx1_1fxy9jgn7ynjkw0000gn/T/ipykernel_4462/3192953128.py:29: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_stat, kpss_p, _, kpss_crit = kpss(ts, regression="c", nlags="auto")
# /var/folders/zz/l0v68lmx1_1fxy9jgn7ynjkw0000gn/T/ipykernel_4462/3192953128.py:29: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_stat, kpss_p, _, kpss_crit = kpss(ts, regression="c", nlags="auto")

# %%
import statsmodels.api as sm

def estimate_ar1(df):
    results = []

    for sector, df_sec in df.groupby("sector"):
        X = sm.add_constant(df_sec["g_lag"])
        y = df_sec["g"]

        model = sm.OLS(y, X, missing="drop").fit()

        alpha = model.params["const"]
        phi = model.params["g_lag"]
        sigma = model.resid.std()

        # OU equivalents
        kappa = 1 - phi
        mu = alpha / kappa if kappa != 0 else np.nan

        results.append({
            "sector": sector,
            "alpha": alpha,
            "phi (persistence)": phi,
            "kappa (speed of mean reversion)": kappa,
            "mu (long-run mean growth)": mu,
            "sigma (volatility)": sigma,
            "n_obs": len(df_sec),
            "n_cik": df_sec["cik"].nunique()
        })

    return pd.DataFrame(results)

sector_params = estimate_ar1(filtered_df)
sector_params
# Out:
#                                sector     alpha  phi (persistence)  \
# 0  Consumer (Staples & Discretionary)  0.047582          -0.054916
# 1  Energy, Utilities & Infrastructure  0.038231          -0.011460
# 2                          Financials  0.050781          -0.008363
# 3         Health Care & Life Sciences  0.147182          -0.227077
# 4          Technology & Communication  0.088234          -0.118181
#
#    kappa (speed of mean reversion)  mu (long-run mean growth)  \
# 0                         1.054916                   0.045105
# 1                         1.011460                   0.037797
# 2                         1.008363                   0.050360
# 3                         1.227077                   0.119945
# 4                         1.118181                   0.078909
#
#    sigma (volatility)  n_obs  n_cik
# 0            0.567234   3303    447
# 1            0.560461   3224    435
# 2            0.698980   3297    470
# 3            1.241660   3985    597
# 4            0.692015   5856    819

# %%
# subsector ar(1). modelling
def estimate_subsector_ar1(growth_panel):
    """
    Estimate AR(1) and OU parameters for each sub-sector.
    Returns a ranking of sub-sectors by persistence, mean reversion, volatility, etc.
    """

    results = []

    for (sector, subsec), df_ss in growth_panel.groupby(["sector", "sub_sector"]):

        if len(df_ss) < 50:  # avoid unstable regressions
            continue

        # AR(1) regression: g_t = alpha + phi * g_{t-1}
        X = sm.add_constant(df_ss["g_lag"])
        y = df_ss["g"]
        model = sm.OLS(y, X, missing="drop").fit()

        alpha = model.params["const"]
        phi   = model.params["g_lag"]
        sigma = model.resid.std()

        # OU equivalents
        kappa = 1 - phi
        mu = alpha / kappa if kappa != 0 else np.nan

        results.append({
            "sector": sector,
            "sub_sector": subsec,
            "alpha": alpha,
            "phi (persistence)": phi,
            "kappa (speed of MR)": kappa,
            "mu (long-run growth)": mu,
            "sigma (volatility)": sigma,
            "n_obs": len(df_ss),
            "n_cik": df_ss["cik"].nunique()
        })

    return pd.DataFrame(results).sort_values(by="sector")

subsector_ar1_results = estimate_subsector_ar1(filtered_df)
subsector_ar1_results
# Out:
#                                 sector  \
# 0   Consumer (Staples & Discretionary)
# 15  Consumer (Staples & Discretionary)
# 14  Consumer (Staples & Discretionary)
# 13  Consumer (Staples & Discretionary)
# 12  Consumer (Staples & Discretionary)
# 11  Consumer (Staples & Discretionary)
# 10  Consumer (Staples & Discretionary)
# 8   Consumer (Staples & Discretionary)
# 9   Consumer (Staples & Discretionary)
# 6   Consumer (Staples & Discretionary)
# 5   Consumer (Staples & Discretionary)
# 4   Consumer (Staples & Discretionary)
# 3   Consumer (Staples & Discretionary)
# 2   Consumer (Staples & Discretionary)
# 1   Consumer (Staples & Discretionary)
# 7   Consumer (Staples & Discretionary)
# 22  Energy, Utilities & Infrastructure
# 24  Energy, Utilities & Infrastructure
# 23  Energy, Utilities & Infrastructure
# 20  Energy, Utilities & Infrastructure
# 21  Energy, Utilities & Infrastructure
# 18  Energy, Utilities & Infrastructure
# 17  Energy, Utilities & Infrastructure
# 16  Energy, Utilities & Infrastructure
# 19  Energy, Utilities & Infrastructure
# 29                          Financials
# 25                          Financials
# 26                          Financials
# 27                          Financials
# 28                          Financials
# 34         Health Care & Life Sciences
# 33         Health Care & Life Sciences
# 32         Health Care & Life Sciences
# 30         Health Care & Life Sciences
# 31         Health Care & Life Sciences
# 40          Technology & Communication
# 41          Technology & Communication
# 39          Technology & Communication
# 42          Technology & Communication
# 37          Technology & Communication
# 36          Technology & Communication
# 35          Technology & Communication
# 38          Technology & Communication
# 43          Technology & Communication
#
#                                            sub_sector     alpha  \
# 0                           Apparel & Clothing Stores  0.020219
# 15                    Soft Drinks & Carbonated Waters  0.088355
# 14                            Retail – Grocery Stores  0.034337
# 13                        Restaurants & Eating Places  0.050340
# 12                                     Packaged Foods -0.016165
# 11     Motion Picture & Video Production/Distribution  0.125983
# 10         Motion Picture & Video Exhibition & Rental  0.054163
# 8                            Hotels, Motels & Lodging  0.054878
# 9                  Household & Personal Care Products  0.052176
# 6                 Home Furniture & Furnishings Stores -0.000631
# 5             General Merchandise & Department Stores -0.018580
# 4                 Entertainment & Recreation Services  0.101159
# 3                        E-Commerce / Nonstore Retail -0.080864
# 2                    Automotive Manufacturing & Parts  0.048952
# 1                     Auto Dealers & Service Stations  0.048557
# 7      Home Improvement & Building Materials (Retail)  0.042331
# 22                                 Petroleum Refining  0.006633
# 24                          Refuse & Waste Management  0.046314
# 23                      Pipelines (Excl. Natural Gas)  0.062984
# 20            Natural Gas Transmission & Distribution  0.130643
# 21               Oil & Gas Field Services & Equipment -0.042322
# 18                 Electric & Other Services Combined  0.041997
# 17                      Crude Petroleum & Natural Gas  0.057575
# 16                            Coal & Consumable Fuels  0.005100
# 19                                  Electric Services  0.018418
# 29                             State Commercial Banks  0.055214
# 25                                  Investment Advice  0.034082
# 26                          National Commercial Banks  0.057108
# 27              Real Estate Investment Trusts (REITs)  0.046012
# 28                         Security Brokers & Dealers  0.092283
# 34                     Surgical & Medical Instruments  0.142418
# 33                        Pharmaceutical Preparations  0.144694
# 32               General Medical & Surgical Hospitals  0.019912
# 30                                Biological Products  0.157209
# 31         Diagnostic Substances (In Vitro & In Vivo)  0.023828
# 40                               Prepackaged Software  0.140405
# 41  Radio & TV Broadcasting & Communications Equip...  0.052966
# 39                      IT Services & Data Processing  0.104402
# 42                   Semiconductors & Related Devices  0.060561
# 37                Electronic Components & Accessories  0.043090
# 36                           Computer Storage Devices -0.010077
# 35                Computer & Office Equipment – Other  0.041038
# 38                               Electronic Computers  0.037675
# 43                                   Telecom Services  0.061364
#
#     phi (persistence)  kappa (speed of MR)  mu (long-run growth)  \
# 0           -0.734502             1.734502              0.011657
# 15          -0.129002             1.129002              0.078259
# 14           0.181097             0.818903              0.041931
# 13           0.178847             0.821153              0.061304
# 12           0.293001             0.706999             -0.022864
# 11          -0.014122             1.014122              0.124228
# 10          -0.172737             1.172737              0.046185
# 8           -0.072235             1.072235              0.051181
# 9           -0.080561             1.080561              0.048286
# 6            0.645387             0.354613             -0.001780
# 5           -0.161917             1.161917             -0.015991
# 4           -0.126434             1.126434              0.089805
# 3            0.007765             0.992235             -0.081497
# 2           -0.129164             1.129164              0.043352
# 1            0.345286             0.654714              0.074166
# 7            0.435883             0.564117              0.075039
# 22          -0.013182             1.013182              0.006547
# 24           0.022467             0.977533              0.047379
# 23           0.133383             0.866617              0.072677
# 20           0.060782             0.939218              0.139097
# 21           0.083779             0.916221             -0.046192
# 18          -0.608463             1.608463              0.026110
# 17          -0.081706             1.081706              0.053226
# 16           0.019442             0.980558              0.005202
# 19           0.168557             0.831443              0.022151
# 29           0.007613             0.992387              0.055637
# 25          -0.123762             1.123762              0.030328
# 26           0.252641             0.747359              0.076413
# 27           0.012899             0.987101              0.046613
# 28          -0.239120             1.239120              0.074474
# 34          -0.027139             1.027139              0.138655
# 33          -0.249899             1.249899              0.115764
# 32           0.163775             0.836225              0.023811
# 30          -0.261024             1.261024              0.124668
# 31           0.071667             0.928333              0.025667
# 40          -0.265637             1.265637              0.110936
# 41          -0.091996             1.091996              0.048504
# 39          -0.014327             1.014327              0.102928
# 42          -0.025545             1.025545              0.059053
# 37          -0.239814             1.239814              0.034755
# 36           0.216644             0.783356             -0.012863
# 35           0.003207             0.996793              0.041170
# 38           0.137783             0.862217              0.043695
# 43           0.072713             0.927287              0.066175
#
#     sigma (volatility)  n_obs  n_cik
# 0             0.346968    284     30
# 15            0.293245     68     10
# 14            0.103930     81     13
# 13            0.421352    499     64
# 12            0.539099    126     19
# 11            1.218094     82     13
# 10            0.411131     94     10
# 8             0.316299    306     44
# 9             0.657017    177     26
# 6             0.129732     79     10
# 5             0.129930     79      9
# 4             0.948528    316     54
# 3             0.846589    200     33
# 2             0.548056    457     65
# 1             0.345462    253     26
# 7             0.205402    118     13
# 22            0.503291    124     19
# 24            0.462953    148     19
# 23            0.390365    137     17
# 20            0.460948    348     52
# 21            0.582558    596     80
# 18            0.295728    250     29
# 17            0.726344    990    141
# 16            0.482755    132     21
# 19            0.332404    420     54
# 29            0.491639    402     84
# 25            0.454671    393     50
# 26            0.312474    228     45
# 27            0.799943   2027    261
# 28            0.647989    247     31
# 34            0.743339    948    131
# 33            1.422985   2232    359
# 32            0.420344     63      9
# 30            1.305552    591     83
# 31            0.554437    151     22
# 40            0.875335   1461    224
# 41            0.674519    669     92
# 39            0.695350   1375    217
# 42            0.534807    879    110
# 37            0.556078    448     58
# 36            0.150092     59      8
# 35            0.277190    340     43
# 38            0.337222     80     10
# 43            0.664894    545     78
